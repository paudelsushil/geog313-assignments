# %%
 # Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generating the array x
x = np.arange(-100, 101, 0.5)

# %%
# Generating the arrays y and z
y = np.cos(x)
z = np.sin(x)

# %%
# Generating the arrays y and z
y = np.cos(x)
z = np.sin(x)

# %%
# Plot 
plt.plot(x, y, label='cos(x)', color='blue')
plt.plot(x, z, label='sin(x)', color='green')
# Add a legend
plt.legend()

# Add x and y axis labels
plt.xlabel('x')
plt.ylabel('y')

# Show the plot
plt.grid(True)
plt.title("Assignment 2")
plt.show()
